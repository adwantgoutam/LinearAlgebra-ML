# %% [markdown]
# # Span, Basis, Rank
#
# Use this notebook to explore the concept visually and with code.
#
# **Tip:** run the matching exercise in `exercises/` too.

# %% [markdown]
# ## Goals
#
# Detect redundancy; understand rank as independent directions.

# %%
# TODO: implement / explore here

# %% [markdown]
# ## Practice
#
# Create dependent/independent vectors, compute rank; test `in_span`.

# %%
# TODO: implement / explore here
