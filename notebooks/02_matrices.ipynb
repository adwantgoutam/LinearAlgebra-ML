# %% [markdown]
# # Matrices & Transformations
#
# Use this notebook to explore the concept visually and with code.
#
# **Tip:** run the matching exercise in `exercises/` too.

# %% [markdown]
# ## Goals
#
# Understand matrix multiplication as transformation + many dot products.

# %%
# TODO: implement / explore here

# %% [markdown]
# ## Practice
#
# Apply rotation/scaling matrices to point clouds and plot.

# %%
# TODO: implement / explore here
