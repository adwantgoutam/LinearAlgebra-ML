# %% [markdown]
# # Vectors for ML
#
# Use this notebook to explore the concept visually and with code.
#
# **Tip:** run the matching exercise in `exercises/` too.

# %% [markdown]
# ## Goals
#
# Build intuition for vectors, norms, dot product, cosine similarity.

# %%
# TODO: implement / explore here

# %% [markdown]
# ## Practice
#
# Try: create random vectors, compute dot, norm, cosine; visualize angles.

# %%
# TODO: implement / explore here
