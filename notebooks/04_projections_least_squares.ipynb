# %% [markdown]
# # Projections & Least Squares
#
# Use this notebook to explore the concept visually and with code.
#
# **Tip:** run the matching exercise in `exercises/` too.

# %% [markdown]
# ## Goals
#
# See linear regression as projection onto column space.

# %%
# TODO: implement / explore here

# %% [markdown]
# ## Practice
#
# Fit a line via normal equation and visualize residuals.

# %%
# TODO: implement / explore here
