# %% [markdown]
# # PCA & SVD
#
# Use this notebook to explore the concept visually and with code.
#
# **Tip:** run the matching exercise in `exercises/` too.

# %% [markdown]
# ## Goals
#
# Learn variance directions and low-rank approximation.

# %%
# TODO: implement / explore here

# %% [markdown]
# ## Practice
#
# Do PCA on synthetic data; reconstruct with low rank; plot error vs rank.

# %%
# TODO: implement / explore here
